# %% [markdown]
# # Criando modelo de classificação por linhagem

# %% [markdown]
# Pergunta - é possivel criar um modelo que classifique as imagens baseado nas imagens?
#
# Aqui, temos 9 linhagens diferentes e o objetivo é criar um modelo que seja capaz de identifica - las através da imagem de microscopia. Para isso, é necessário criar 9 classes diferentes (rótulos) e criar um modelo de multiclasses.

# %% [markdown]
# Como colocar os rótulos (y) em 9 classes (categorias) diferentes?

# %% [markdown]
# Importação das Bibliotecas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install util-gfsilveira
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#encontrar e caminhar pelos arquivos
import os
#estruturação dos dados de imagens para matriz numérica
import numpy as np
#salvar os dados em diferentes arquivos
import joblib
#deixando os arquivos salvos com a data do dia que o código correu
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis

# %%
#serve para adicionar data 
data = timeProcess()[1]

# %% [markdown]
# # Listas de imagens de todas as linhagens

# %%
#buscando no drive a pasta onde está a lista de imagens já "aumentadas"
diretorio = "/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imag_rot_linhagens_para_orga_14_03_23"
lista_dados = os.listdir(diretorio)
printLis(lista_dados)
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> lista_img_camp_clar_100_resized_class_A549-2023-3-14.gz
# 1 -> lista_rotulos_camp_clar_100_resized_class_A549-2023-3-14.gz
# 2 -> lista_img_camp_clar_75_resized_class_A549-2023-3-14.gz
# 3 -> lista_rotulos_camp_clar_75_resized_class_A549-2023-3-14.gz
# 4 -> lista_img_camp_clar_50_resized_class_A549-2023-3-14.gz
# 5 -> lista_rotulos_camp_clar_50_resized_class_A549-2023-3-14.gz
# 6 -> lista_img_camp_clar_25_resized_class_A549-2023-3-14.gz
# 7 -> lista_rotulos_camp_clar_25_resized_class_A549-2023-3-14.gz
# 8 -> lista_img_camp_clar_100_resized_class_huh7-2023-3-14.gz
# 9 -> lista_rotulos_camp_clar_100_resized_class_huh7-2023-3-14.gz
# 10 -> lista_img_camp_clar_75_resized_class_HUH7-2023-3-14.gz
# 11 -> lista_rotulos_camp_clar_75_resized_class_HUH7-2023-3-14.gz
# 12 -> lista_img_camp_clar_50_resized_class_HUH7-2023-3-14.gz
# 13 -> lista_rotulos_camp_clar_50_resized_class_HUH7-2023-3-14.gz
# ...

# %% [markdown]
# somando as imagens de cada linhagem

# %% [markdown]
# Linhagem THP1

# %% [markdown]
# imagens THP1

# %%
imagem_thp_cem = joblib.load(diretorio+ '/' + lista_dados[30])
imagem_thp_set = joblib.load(diretorio+ '/' + lista_dados[32])
imagem_thp_ciq = joblib.load(diretorio+ '/' + lista_dados[34])
imagem_thp_vin = joblib.load(diretorio+ '/' + lista_dados[36])


# imagem_thp_soma = np.asarray(list(imagem_thp_cem) + list(imagem_thp_set) + list(imagem_thp_ciq) + list(imagem_thp_vin)) #somando os valores de cada lista
# imagem_thp_soma.shape

# %%
imagem_thp_soma = np.asarray(list(imagem_thp_cem) + list(imagem_thp_set) + list(imagem_thp_ciq) + list(imagem_thp_vin)) #somando os valores de cada lista
imagem_thp_soma.shape
# Out:
# (1696, 200, 200, 3)

# %%
joblib.dump(imagem_thp_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_THP1'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_THP12023-3-15.gz']

# %% [markdown]
# imagens SH-SY5Y

# %%
imagem_sh_cem = joblib.load(diretorio+ '/' + lista_dados[38])
imagem_sh_set = joblib.load(diretorio+ '/' + lista_dados[40])
imagem_sh_ciq = joblib.load(diretorio+ '/' + lista_dados[42])
imagem_sh_vin = joblib.load(diretorio+ '/' + lista_dados[44])

# %%
imagem_sh_soma = np.asarray(list(imagem_sh_cem) + list(imagem_sh_set) + list(imagem_sh_ciq) + list(imagem_sh_vin)) #somando os valores de cada lista
imagem_sh_soma.shape
joblib.dump(imagem_sh_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_SH-SY5Y'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_SH-SY5Y2023-3-15.gz']

# %%
imagem_sh_soma.shape
# Out:
# (1168, 200, 200, 3)

# %% [markdown]
# imagens A172

# %%
imagem_A172_cem = joblib.load(diretorio+ '/' + lista_dados[46])
imagem_A172_set = joblib.load(diretorio+ '/' + lista_dados[48])
imagem_A172_ciq = joblib.load(diretorio+ '/' + lista_dados[50])
imagem_A172_vin = joblib.load(diretorio+ '/' + lista_dados[52])

# %%
imagem_A172_soma = np.asarray(list(imagem_A172_cem) + list(imagem_A172_set) + list(imagem_A172_ciq) + list(imagem_A172_vin)) #somando os valores de cada lista
imagem_A172_soma.shape
joblib.dump(imagem_A172_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_A172-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_A172-2023-3-15.gz']

# %%
imagem_A172_soma.shape
# Out:
# (1584, 200, 200, 3)

# %% [markdown]
# imagens MAYV

# %%
imagem_mayv_cem = joblib.load(diretorio+ '/' + lista_dados[54])
imagem_mayv_set = joblib.load(diretorio+ '/' + lista_dados[56])
imagem_mayv_ciq = joblib.load(diretorio+ '/' + lista_dados[58])
imagem_mayv_vin = joblib.load(diretorio+ '/' + lista_dados[60])

# %%
imagem_mayv_soma = np.asarray(list(imagem_mayv_cem) + list(imagem_mayv_set) + list(imagem_mayv_ciq) + list(imagem_mayv_vin)) #somando os valores de cada lista
imagem_mayv_soma.shape
joblib.dump(imagem_mayv_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_MAYV-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_MAYV-2023-3-15.gz']

# %%
imagem_mayv_soma.shape
# Out:
# (1280, 200, 200, 3)

# %% [markdown]
# imagens DENV

# %%
imagem_denv_cem = joblib.load(diretorio+ '/' + lista_dados[62])
imagem_denv_set = joblib.load(diretorio+ '/' + lista_dados[64])
imagem_denv_ciq = joblib.load(diretorio+ '/' + lista_dados[66])
imagem_denv_vin = joblib.load(diretorio+ '/' + lista_dados[68])

# %%
imagem_denv_soma = np.asarray(list(imagem_denv_cem) + list(imagem_denv_set) + list(imagem_denv_ciq) + list(imagem_denv_vin)) #somando os valores de cada lista
imagem_denv_soma.shape
joblib.dump(imagem_denv_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_DENV-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_DENV-2023-3-15.gz']

# %% [markdown]
# imagens VERO6

# %%
imagem_vero_cem = joblib.load(diretorio+ '/' + lista_dados[65])
imagem_vero_set = joblib.load(diretorio+ '/' + lista_dados[67])
imagem_vero_ciq = joblib.load(diretorio+ '/' + lista_dados[69])
imagem_vero_vin = joblib.load(diretorio+ '/' + lista_dados[71])

# %%
imagem_vero_soma = np.asarray(list(imagem_vero_cem) + list(imagem_vero_set) + list(imagem_vero_ciq) + list(imagem_vero_vin)) #somando os valores de cada lista
imagem_vero_soma.shape
joblib.dump(imagem_vero_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_VERO6-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_VERO6-2023-3-15.gz']

# %%
imagem_vero_soma.shape
# Out:
# (1792, 200, 200, 3)

# %% [markdown]
# imagens A549

# %%
imagem_A549_cem = joblib.load(diretorio+ '/' + lista_dados[0])
imagem_A549_set = joblib.load(diretorio+ '/' + lista_dados[2])
imagem_A549_ciq = joblib.load(diretorio+ '/' + lista_dados[4])
imagem_A549_vin = joblib.load(diretorio+ '/' + lista_dados[6])

# %%
imagem_A549_soma = np.asarray(list(imagem_A549_cem) + list(imagem_A549_set) + list(imagem_A549_ciq) + list(imagem_A549_vin)) #somando os valores de cada lista
imagem_A549_soma.shape
joblib.dump(imagem_A549_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_A549-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_A549-2023-3-15.gz']

# %%
imagem_A549_soma.shape
# Out:
# (1136, 200, 200, 3)

# %% [markdown]
# imagens HUH7

# %%
imagem_Huh7_cem = joblib.load(diretorio+ '/' + lista_dados[8])
imagem_Huh7_set = joblib.load(diretorio+ '/' + lista_dados[10])
imagem_Huh7_ciq = joblib.load(diretorio+ '/' + lista_dados[12])
imagem_Huh7_vin = joblib.load(diretorio+ '/' + lista_dados[14])

# %%
imagem_Huh7_soma = np.asarray(list(imagem_Huh7_cem) + list(imagem_Huh7_set) + list(imagem_Huh7_ciq) + list(imagem_Huh7_vin)) #somando os valores de cada lista
imagem_Huh7_soma.shape
joblib.dump(imagem_Huh7_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_HUH7-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_HUH7-2023-3-15.gz']

# %%
imagem_Huh7_soma.shape
# Out:
# (704, 200, 200, 3)

# %% [markdown]
# imagens 3T3

# %%
imagem_3T3_cem = joblib.load(diretorio+ '/' + lista_dados[16])
imagem_3T3_set = joblib.load(diretorio+ '/' + lista_dados[18])
imagem_3T3_ciq = joblib.load(diretorio+ '/' + lista_dados[20])
imagem_3T3_vin = joblib.load(diretorio+ '/' + lista_dados[22])

# %%
imagem_3T3_soma = np.asarray(list(imagem_3T3_cem) + list(imagem_3T3_set) + list(imagem_3T3_ciq) + list(imagem_3T3_vin)) #somando os valores de cada lista
imagem_3T3_soma.shape
joblib.dump(imagem_3T3_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_3T3-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_imagens_3T3-2023-3-15.gz']

# %%
imagem_3T3_soma.shape
# Out:
# (832, 200, 200, 3)

# %%
soma_imagens = np.asarray(list(imagem_thp_soma) + list(imagem_sh_soma) + list(imagem_mayv_soma)
                          + list(imagem_A172_soma) + list(imagem_denv_soma) + list(imagem_vero_soma)
                          + list(imagem_A549_soma) + list(imagem_Huh7_soma) + list(imagem_3T3_soma))
soma_imagens.shape
# Out:
# (11712, 200, 200, 3)

# %%
joblib.dump(soma_imagens, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_de_todas_imagens-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_de_todas_imagens-2023-3-15.gz']

# %% [markdown]
# Somando todas as imagens do banco

# %% [markdown]
# **TRABALHANDO COM OS RÓTULOS**

# %% [markdown]
# Rótulo THP1

# %%
rot_thp_cem = joblib.load(diretorio+ '/' + lista_dados[26])
rot_thp_set = joblib.load(diretorio+ '/' + lista_dados[28])
rot_thp_ciq = joblib.load(diretorio+ '/' + lista_dados[30])
rot_thp_vin = joblib.load(diretorio+ '/' + lista_dados[32])
# rot_thp_soma = np.asarray(list(rot_thp_cem) + list(rot_thp_set) + list(rot_thp_ciq) + list(rot_thp_vin)) #somando os valores de cada lista
# rot_thp_soma.shape

# %%
rot_thp_soma = np.asarray(list(rot_thp_cem) + list(rot_thp_set) + list(rot_thp_ciq) + list(rot_thp_vin)) #somando os valores de cada lista
rot_thp_soma.shape
joblib.dump(rot_thp_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_THP1-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_THP1-2023-3-15.gz']

# %%
rot_thp_soma.shape
# Out:
# (1696,)

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM THP = 1
rot_thp_soma[rot_thp_soma == 'THP1' ] = 1

# %%
#conferindo se deu certo. E deu.
rot_thp_soma.shape
# Out:
# (1696,)

# %% [markdown]
# Rótulo SH-SY5Y

# %%
rot_sh_cem = joblib.load(diretorio+ '/' + lista_dados[34])
rot_sh_set = joblib.load(diretorio+ '/' + lista_dados[36])
rot_sh_ciq = joblib.load(diretorio+ '/' + lista_dados[38])
rot_sh_vin = joblib.load(diretorio+ '/' + lista_dados[40])

# %%
rot_sh_soma = np.asarray(list(rot_sh_cem) + list(rot_sh_set) + list(rot_sh_ciq) + list(rot_sh_vin)) #somando os valores de cada lista
rot_sh_soma.shape
joblib.dump(rot_sh_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_SH-SY5Y-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_SH-SY5Y-2023-3-15.gz']

# %%
rot_sh_soma.shape
# Out:
# (1168,)

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM SH-SY = 2
rot_sh_soma[rot_sh_soma == 'SH-SY5Y' ] = 2

# %%
rot_sh_soma.shape
# Out:
# (1168,)

# %% [markdown]
# Rótulos A172

# %%
rot_A172_cem = joblib.load(diretorio+ '/' + lista_dados[42])
rot_A172_set = joblib.load(diretorio+ '/' + lista_dados[44])
rot_A172_ciq = joblib.load(diretorio+ '/' + lista_dados[46])
rot_A172_vin = joblib.load(diretorio+ '/' + lista_dados[48])

# %%
rot_A172_soma = np.asarray(list(rot_A172_cem) + list(rot_A172_set) + list(rot_A172_ciq) + list(rot_A172_vin)) #somando os valores de cada lista
rot_A172_soma.shape
joblib.dump(rot_A172_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_A172-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_A172-2023-3-15.gz']

# %%
rot_A172_soma.shape
# Out:
# (1584,)

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM A172 = 3
rot_A172_soma[rot_A172_soma == 'A172' ] = 3

# %%
rot_A172_soma.shape
# Out:
# (1584,)

# %% [markdown]
# Rótulos MAYV

# %%
rot_mayv_cem = joblib.load(diretorio+ '/' + lista_dados[50])
rot_mayv_set = joblib.load(diretorio+ '/' + lista_dados[52])
rot_mayv_ciq = joblib.load(diretorio+ '/' + lista_dados[54])
rot_mayv_vin = joblib.load(diretorio+ '/' + lista_dados[56])

# %%
rot_mayv_soma = np.asarray(list(rot_mayv_cem) + list(rot_mayv_set) + list(rot_mayv_ciq) + list(rot_mayv_vin)) #somando os valores de cada lista
rot_mayv_soma.shape
joblib.dump(rot_mayv_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_MAYV-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_MAYV-2023-3-15.gz']

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM MAYV = 4
rot_mayv_soma[rot_mayv_soma == 'MAYV' ] = 4

# %%
rot_mayv_soma.shape
# Out:
# (1280,)

# %% [markdown]
# Rótulos DENV

# %%
rot_denv_cem = joblib.load(diretorio+ '/' + lista_dados[58])
rot_denv_set = joblib.load(diretorio+ '/' + lista_dados[60])
rot_denv_ciq = joblib.load(diretorio+ '/' + lista_dados[62])
rot_denv_vin = joblib.load(diretorio+ '/' + lista_dados[64])

# %%
rot_denv_soma = np.asarray(list(rot_denv_cem) + list(rot_denv_set) + list(rot_denv_ciq) + list(rot_denv_vin)) #somando os valores de cada lista
rot_denv_soma.shape
joblib.dump(rot_denv_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_DENV-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_DENV-2023-3-15.gz']

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM DENV = 5
rot_denv_soma[rot_denv_soma == 'mAb_DENV1' ] = 5

# %%
rot_denv_soma.shape
# Out:
# (1520,)

# %% [markdown]
# Rótulos VERO6

# %%
rot_vero_cem = joblib.load(diretorio+ '/' + lista_dados[66])
rot_vero_set = joblib.load(diretorio+ '/' + lista_dados[68])
rot_vero_ciq = joblib.load(diretorio+ '/' + lista_dados[70])
rot_vero_vin = joblib.load(diretorio+ '/' + lista_dados[72])

# %%
rot_vero_soma = np.asarray(list(rot_vero_cem) + list(rot_vero_set) + list(rot_vero_ciq) + list(rot_vero_vin)) #somando os valores de cada lista
rot_vero_soma.shape
joblib.dump(rot_vero_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_VERO6-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_VERO6-2023-3-15.gz']

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM VERO = 6
rot_vero_soma[rot_vero_soma == 'VERO6' ] = 6

# %%
rot_vero_soma.shape
# Out:
# (1792,)

# %%
rot_A549_cem = joblib.load(diretorio+ '/' + lista_dados[1])
rot_A549_set = joblib.load(diretorio+ '/' + lista_dados[3])
rot_A549_ciq = joblib.load(diretorio+ '/' + lista_dados[5])
rot_A549_vin = joblib.load(diretorio+ '/' + lista_dados[7])

# %% [markdown]
# Rótulos A549

# %%
rot_A549_soma = np.asarray(list(rot_A549_cem) + list(rot_A549_set) + list(rot_A549_ciq) + list(rot_A549_vin)) #somando os valores de cada lista
rot_A549_soma.shape
joblib.dump(rot_A549_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_A549-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_A549-2023-3-15.gz']

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM A549 = 7
rot_A549_soma[rot_A549_soma == 'A549' ] = 7

# %%
rot_A549_soma.shape
# Out:
# (1136,)

# %% [markdown]
# Rótulos Huh7

# %%
rot_Huh7_cem = joblib.load(diretorio+ '/' + lista_dados[9])
rot_Huh7_set = joblib.load(diretorio+ '/' + lista_dados[11])
rot_Huh7_ciq = joblib.load(diretorio+ '/' + lista_dados[13])
rot_Huh7_vin = joblib.load(diretorio+ '/' + lista_dados[15])

# %%
rot_Huh7_soma = np.asarray(list(rot_Huh7_cem) + list(rot_Huh7_set) + list(rot_Huh7_ciq) + list(rot_Huh7_vin)) #somando os valores de cada lista
rot_Huh7_soma.shape
joblib.dump(rot_Huh7_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_HUH7-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_HUH7-2023-3-15.gz']

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM HUH7 = 8
rot_Huh7_soma[rot_Huh7_soma == 'ajuste_huh7' ] = 'Huh7'

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM Huh7 = 8
rot_Huh7_soma[rot_Huh7_soma == 'Huh7' ] = 8

# %%
rot_Huh7_soma.shape
# Out:
# (704,)

# %% [markdown]
# Rótulos 3T3

# %%
rot_3T3_cem = joblib.load(diretorio+ '/' + lista_dados[17])
rot_3T3_set = joblib.load(diretorio+ '/' + lista_dados[19])
rot_3T3_ciq = joblib.load(diretorio+ '/' + lista_dados[21])
rot_3T3_vin = joblib.load(diretorio+ '/' + lista_dados[23])

# %%
rot_3T3_soma = np.asarray(list(rot_3T3_cem) + list(rot_3T3_set) + list(rot_3T3_ciq) + list(rot_3T3_vin)) #somando os valores de cada lista
rot_3T3_soma.shape
joblib.dump(rot_3T3_soma, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_3T3-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/rotulos_somados_3T3-2023-3-15.gz']

# %%
#substituindo o nome da linhagem por uma classe numérica - LINHAGEM 3T3 = 9
rot_3T3_soma[rot_3T3_soma == '3T3' ] = 9

# %%
rot_3T3_soma.shape
# Out:
# (832,)

# %% [markdown]
# Somando todos os rótulos com cada classe

# %%
soma_rot_class = np.asarray(list(rot_thp_soma) + list(rot_sh_soma) + list(rot_mayv_soma) + list(rot_A172_soma) +
                        list(rot_denv_soma) + list(rot_vero_soma) + list(rot_A549_soma) + list(rot_Huh7_soma) +
                        list(rot_3T3_soma))

# %%
joblib.dump(soma_rot_class, '/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_de_todos_rótulos-'+data+'.gz')
# Out:
# ['/content/drive/MyDrive/Classificação_imagens_DOC_CNN/imagens e rótulos para classificação 14-03-23/soma_de_todos_rótulos-2023-3-15.gz']

# %%
#vendo se a soma deu certo
soma_rot_class.shape
# Out:
# (11712,)
